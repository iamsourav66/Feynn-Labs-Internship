# %% [markdown]
# ### **Imports**

# %%
# importing the dependencies
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans

# %% [markdown]
# ### **Fetching Datasets**

# %%
# fetching dataset - 1
df1 = pd.read_csv(r'C:\Users\SOURAV\Desktop\charger_dataset.csv')
df1.head()
# Out:
#           Region     2W     3W    4W  Bus  Chargers
# 0  Uttar Pradesh   9852  42881   458  197       207
# 1     Maharastra  38558    893  1895  186       317
# 2      Karnataka  32844    568   589   57       172
# 3     Tamil Nadu  25642    396   426    0       256
# 4        Gujarat  22359    254   423   22       228

# %%
# fetching dataset - 2
df2 = pd.read_excel(r'C:\Users\SOURAV\Desktop\charging_station_dataset.xlsx', sheet_name='Table 4', header=1)
df2.head()
# Out:
#             State/UT  EV Charging Facility
# 0     Andhra Pradesh                    65
# 1  Arunachal Pradesh                     4
# 2              Assam                    19
# 3              Bihar                    26
# 4         Chandigarh                     4

# %%
# fetching dataset - 3
df3 = pd.read_excel(r'C:\Users\SOURAV\Desktop\EVmarket_india_dataset.xlsx')
df3.head()
# Out:
#         Brand                          Model  AccelSec  TopSpeed_KmH  \
# 0       Tesla  Model 3 Long Range Dual Motor       4.6           233
# 1  Volkswagen                      ID.3 Pure      10.0           160
# 2    Polestar                              2       4.7           210
# 3         BMW                            iX3       6.8           180
# 4       Honda                              e       9.5           145
#
#    Range_Km  Efficiency_WhKm  FastCharge_KmH RapidCharge PowerTrain  \
# 0       450              161             940         Yes        AWD
# 1       270              167             250          No        RWD
# 2       400              181             620         Yes        AWD
# 3       360              206             560         Yes        RWD
# 4       170              168             190         Yes        RWD
#
#      PlugType  BodyStyle Segment  Seats  PriceEuro
# 0  Type 2 CCS      Sedan       D      5      55480
# ...

# %% [markdown]
# ### **Exploratory Data Analysis (EDA)**

# %% [markdown]
# ### *Analysing the datasets*

# %%
# checking the shape (# of rows and columns) of the datasets
print('DF1 Shape: ', df1.shape)
print('DF2 Shape: ', df2.shape)
print('DF3 Shape: ', df3.shape)
# Out:
# DF1 Shape:  (24, 6)
# DF2 Shape:  (31, 2)
# DF3 Shape:  (103, 14)

# %%
# checking the info (columns, datatypes, nulls) of the datasets
print(' <<< DATASET 1 -----------------------------------------------------------')
print(df1.info())
print(' <<< DATASET 2 -----------------------------------------------------------')
print(df2.info())
print(' <<< DATASET 3 -----------------------------------------------------------')
print(df3.info())
# Out:
#  <<< DATASET 1 -----------------------------------------------------------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24 entries, 0 to 23
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Region    24 non-null     object
#  1   2W        24 non-null     int64
#  2   3W        24 non-null     int64
#  3   4W        24 non-null     int64
#  4   Bus       24 non-null     int64
#  5   Chargers  24 non-null     int64
# dtypes: int64(5), object(1)
# memory usage: 1.2+ KB
# None
#  <<< DATASET 2 -----------------------------------------------------------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31 entries, 0 to 30
# Data columns (total 2 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   State/UT              31 non-null     object
#  1   EV Charging Facility  31 non-null     int64
# dtypes: int64(1), object(1)
# ...

# %%
# getting a statistical summary of the datasets
d1 = df1.describe()
d2 = df2.describe()
d3 = df3.describe()
display('<<< DATASET 1 >>>', d1, '<<< DATASET 2 >>>', d2, '<<< DATASET 3 >>>', d3)
# Out:
# '<<< DATASET 1 >>>'
#                  2W            3W           4W         Bus    Chargers
# count     24.000000     24.000000    24.000000   24.000000   24.000000
# mean    8421.458333   3853.166667   334.041667   28.500000  106.791667
# std    10942.261145   8850.690961   476.930628   63.771331   96.623869
# min      187.000000    234.000000    12.000000    0.000000   10.000000
# 25%      848.000000    512.750000    34.750000    0.000000   25.000000
# 50%     2967.500000    931.000000   129.000000    0.000000   67.500000
# 75%    10697.750000   2659.250000   434.000000    5.500000  180.250000
# max    38558.000000  42881.000000  1895.000000  197.000000  317.000000
# '<<< DATASET 2 >>>'
#        EV Charging Facility
# count             31.000000
# mean              49.548387
# std               50.768651
# min                1.000000
# 25%                4.000000
# 50%               26.000000
# 75%               81.500000
# max              174.000000
# '<<< DATASET 3 >>>'
# ...

# %% [markdown]
# ### *Analysis of 2-wheeler EVs*
# Observation: Maharashtra, Gujarat, Tamilnadu, Karnataka and Andhra Pradesh are among the top states with the majority of EV 2-wheelers while Assam, Himachal Pradesh, Sikkim, J&K with the least.

# %%
# 2 wheelers data visualization from dataset 1
plt.figure(figsize=(6, 6))
sns.barplot(data=df1, y=df1['Region'].sort_values(ascending=True), x='2W', palette='viridis')
plt.ylabel('State', fontsize=14, family='arial')
plt.xlabel('Number of EV: 2 Wheelers', family='arial', fontsize=14, labelpad=10)
plt.xticks(family='arial')
plt.yticks(family='arial')
plt.title(label='Statewise Electric Vehicles (2 Wheelers) in India', weight=100, family='arial', size=15, pad=12)
plt.show()

# %% [markdown]
# ### *Analysis of 3-wheeler EVs*
# Observation: Uttar Pradesh, Assam and Bihar are among the top states with the majority of EV 3-wheelers while the remaining states don't seem to depend on the same.

# %%
# 3 wheelers data visualization from dataset 1
plt.figure(figsize=(6, 6))
sns.barplot(data=df1, y=df1['Region'].sort_values(ascending=True), x='3W', palette='viridis')
plt.ylabel('State', fontsize=14, family='arial')
plt.xlabel('Number of EV: 3 Wheelers', family='arial', fontsize=14, labelpad=10)
plt.xticks(family='arial')
plt.yticks(family='arial')
plt.title(label='Statewise Electric Vehicles (3 Wheelers) in India', weight=100, family='arial', size=15, pad=12)
plt.show()

# %% [markdown]
# ### *Analysis 4-wheeler EVs*
# Observation: Maharashtra, Delhi, Karnataka, Kerala and Andhra Pradhesh are among the top states with the majority of EV 4-wheelers while the remaining states have less number of EV 4-wheelers.

# %%
# 4 wheelers data visualization from dataset 1
plt.figure(figsize=(6, 6))
sns.barplot(data=df1, y=df1['Region'].sort_values(ascending=True), x='4W', palette='viridis')
plt.ylabel('State', fontsize=14, family='arial')
plt.xlabel('Number of EV: 4 Wheelers', family='arial', fontsize=14, labelpad=10)
plt.xticks(family='arial')
plt.yticks(family='arial')
plt.title(label='Statewise Electric Vehicles (4 Wheelers) in India', weight=100, family='arial', size=15, pad=12)
plt.show()

# %% [markdown]
# ### *Analysis of charging stations sanctioned*
# Observation: Maharashtra, Gujarat, Karnataka, Kerala, Uttar Pradesh, Rajasthan, and Andhra Pradhesh are among the top states with the majority of EV charging stations sanctioned while the remaining states have less number of the same.

# %%
# charging stations sanctioned visualization from dataset 1
plt.figure(figsize=(6, 6))
sns.barplot(data=df1, y=df1['Region'].sort_values(ascending=True), x='Chargers', palette='viridis')
plt.ylabel('State', fontsize=14, family='arial')
plt.xlabel('Number of Charging Stations', family='arial', fontsize=14, labelpad=10)
plt.xticks(family='arial')
plt.yticks(family='arial')
plt.title(label='Number of Charging Stations Sanctioned in India', weight=100, family='arial', size=15, pad=12)
plt.show()

# %% [markdown]
# ### *Analysis of retail outlets for EV charging*
# Observation: Rajasthan, Madhya Pradesh, Maharashtra, Karnataka, Uttar Pradesh are among the top states with the majority of retail outlets for EV charging while the remaining states have less number of the same.

# %%
# retail outlets visualization from dataset - 2
plt.figure(figsize=(6, 8))
sns.pointplot(data=df2, y='State/UT', x='EV Charging Facility', color='red')
plt.xlabel('Number of Retail Outlets for Charging EVs', family='arial', size=12, labelpad=10)
plt.ylabel('State/Ut', family='arial', size=12)
plt.tick_params(direction='inout')
plt.xticks(family='arial', size=10)
plt.yticks(family='arial', size=10)
plt.title(label='Available Retail Outlets for Charging EVs in India', weight=100, family='arial', size=15, pad=12)
plt.show()

# %% [markdown]
# ### *Analysis of EVs based on brands*
# Observation: Tesla, Audi, Volkswagen, Nissan, Skoda tops the list of EVs with the maximum number of models in the Indian automobile market.

# %%
# brand-wise count of EV models
sns.catplot(data=df3, x='Brand', kind='count', palette='viridis', height=6, aspect=2)
sns.despine(right=False, top=False)
plt.tick_params(axis='x', rotation=40)
plt.xlabel('Brand',family='arial', size=12)
plt.ylabel('Count', family='arial', size=12)
plt.xticks(family='arial')
plt.yticks(family='arial')
plt.title('Number of EV Models Manufactured by a Brand', family='arial', size=15)
plt.show()

# %% [markdown]
# ### *Anaysis of different body types of EVs*
# Observation: SUV and Hatchback body types form the majority while Station and MPV the minority.

# %%
# different body types EVs visualization from dataset 3
x = df3['BodyStyle'].value_counts().plot.pie(radius=2, cmap='viridis', startangle=0, textprops=dict(family='arial'))
plt.pie(x=[1], radius=1.2, colors='white')
plt.title(label='Electric Vehicles of Different Body Types in India', family='arial', size=15, pad=100)
plt.ylabel('')
plt.show()

# %% [markdown]
# ### *Analysis of different segments of EVs*
# Observation: B and C body segments form the majority while S and A the minority.

# %%
# analysis of different segments of EVs from dataset 3
x = df3['Segment'].value_counts().plot.pie(radius=2, cmap='viridis', startangle=0, textprops=dict(family='arial'), pctdistance=.5)
plt.pie(x=[1], radius=1.2, colors='white')
plt.title(label='Electric Vehicles of Different Segments in India', family='arial', size=15, pad=100)
plt.ylabel('')
plt.show()

# %% [markdown]
# ### *Analysis of EVs of different number of seats*
# Observation: EVs with 5 sitters dominate the market while EVs with 2 sitters are less in number.

# %%
# EVs of different number of seats from dataset 3
sns.countplot(data=df3, x='Seats', palette='viridis')
plt.xlabel('Number of Seats', family='arial', size=12)
plt.ylabel('Count', family='serif', size=12)
plt.xticks(family='arial')
plt.yticks(family='arial')
plt.title(label='Available Electric Vehicles of Different Number of Seats in India', family='arial', size=15, pad=12)
plt.show()

# %% [markdown]
# ### *Analysis of the number of seats by each brand*
# Observation: Based on the number of seats, Tesla, Mercedes and Nissan have the maximum number of seats and Smart the minimum.

# %%
# brand-wise analysis of the number of seats
sns.catplot(kind='bar', data=df3, x='Brand', y='Seats', palette='viridis', ci=None, height=6, aspect=2)
sns.despine(right=False, top=False)
plt.tick_params(axis='x', rotation=40)
plt.xlabel('Brand',family='arial', size=12)
plt.ylabel('Number of Seats', family='arial', size=12)
plt.xticks(family='arial')
plt.yticks(family='arial')
plt.title('Brand-wise Analysis of the Number of Seats', family='arial', size=15);

# %% [markdown]
# ### *Analysis of different plug types*
# Observation: EVs with plus type of 'Type 2 CCS' seem to dominate the market.

# %%
# plug types visualization from dataset 3
df3['PlugType'].value_counts().sort_values(ascending=True).plot.barh()
plt.xlabel('Count', family='arial', size=12)
plt.ylabel('Plug Type', family='arial', size=12)
plt.xticks(family='arial')
plt.yticks(family='arial')
plt.title('Available Plug Types of EVs in India', family='arial', size=14)
plt.show()

# %%
# plotting the price from dataset 3
plt.plot(df3['PriceEuro'], color='red')
plt.xlabel('Number of Samples', family='arial', size=12)
plt.ylabel('Price', family='arial', size=12)
plt.title('Price Comparison', family='arial', size=15, pad=12);

# %% [markdown]
# ### *Analysis of EVs based on accleration*
# Observation: Based on accleration, EVs from Renault, Seat and Smart are the top performers while Tesla, Lucid and Porsche dont make it to the same.

# %%
# accleration visualization from dataset 3
plt.figure(figsize=(6, 8))
sns.barplot(data=df3, y='Brand', x='AccelSec', ci=None, palette='viridis')
plt.xticks(family='arial')
plt.yticks(family='arial')
plt.xlabel('Accleration', family='arial', size=12)
plt.ylabel('Brand', family='arial', size=12)
plt.title(label='Accleration of EVs in India', family='arial', size=15, pad=12)
plt.show()

# %% [markdown]
# ### *Analysis of EVs based on speed*
# Observation: Based on speed parameter, EVs from Tesla, Lucid and Porsche are the top performers while Renault, Smart and SEAT dont make it to the same.

# %%
# speed visualization from dataset 3
plt.figure(figsize=(6, 8))
sns.barplot(data=df3, x='TopSpeed_KmH', y='Brand', ci=None, palette='viridis')
plt.xticks(family='arial')
plt.yticks(family='arial')
plt.xlabel('Max Speed', family='arial', size=12)
plt.ylabel('Brand', family='arial', size=12)
plt.title(label='Brand-wise Speed Comparison of EVs in India', family='arial', size=15, pad=12)
plt.show()

# %%
# plotting the correlation matrix from dataset 3
plt.figure(figsize=(6,6))
sns.heatmap(data=df3.corr(), annot=True, cmap='Blues', cbar=False, square=True, fmt='.2f', linewidths=.3)
plt.title('Correlation Matrix', family='arial', size=15, pad=12);

# %% [markdown]
# ### *Analysis of EVs based on the range parameter*
# Observation: Based on range (Km), Lucid, Lightyear and Tesla have the highest range and Smart the lowest.

# %%
# brand-wise analysis of the range parameter
sns.catplot(kind='bar', data=df3, x='Brand', y='Range_Km', palette='viridis', ci=None, height=6, aspect=2)
sns.despine(right=False, top=False)
plt.tick_params(axis='x', rotation=40)
plt.xlabel('Brand',family='arial', size=12)
plt.ylabel('Range', family='arial', size=12)
plt.xticks(family='arial')
plt.yticks(family='arial')
plt.title('Brand-wise Analysis of the Range Parameter', family='arial', size=15);

# %% [markdown]
# ### **Model Building Using K-Means Clusteing**

# %%
# encoding the categorical features

# PowerTrain feature
df3['PowerTrain'].replace(to_replace=['RWD','FWD','AWD'],value=[0, 1, 2],inplace=True)

# RapidCharge feature
df3['RapidCharge'].replace(to_replace=['No','Yes'],value=[0, 1],inplace=True)

# %%
# selecting features for building a model
X = df3[['AccelSec','TopSpeed_KmH','Efficiency_WhKm','FastCharge_KmH', 'Range_Km', 'RapidCharge', 'Seats', 'PriceEuro','PowerTrain']]

# %%
# feature scaling
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
# applying Principle Component Analysis (PCA)
pca = PCA(n_components=9)
X_pca = pca.fit_transform(X_scaled)
df_pca = pd.DataFrame(X_pca, columns=['PC1', 'PC2', 'PC3', 'PC4', 'PC5', 'PC6', 'PC7', 'PC8', 'PC9'])
df_pca.head()
# Out:
#         PC1       PC2       PC3       PC4       PC5       PC6       PC7  \
# 0  2.429225 -0.554599 -1.147772 -0.882791  0.839988 -0.959297  0.998880
# 1 -2.322483 -0.345449  0.896473 -1.305529  0.079598  0.235116 -0.213678
# 2  1.587851  0.008899 -0.650523  0.041024  0.593537 -0.698248  0.058718
# 3  0.291018 -0.000150 -0.307702 -0.514196 -1.608861  0.291624  0.364999
# 4 -2.602679 -0.626489 -0.888088  0.585294 -0.802108  0.027387 -0.084955
#
#         PC8       PC9
# 0  0.711148 -0.396662
# 1 -0.544135 -0.181867
# 2  0.248837 -0.202775
# 3 -0.235543  0.261663
# 4 -0.507790 -0.049904

# %%
# plotting the results of Elbow

wcss = []

for i in range(1, 11):
  kmean = KMeans(n_clusters=i, init='k-means++', random_state=90)
  kmean.fit(X_pca)
  wcss.append(kmean.inertia_)

plt.figure(figsize=(8,6))
plt.title('Plot of the Elbow Method', size=15, family='arial')
plt.plot(range(1, 11), wcss)
plt.xticks(range(1, 11), family='arial')
plt.yticks(family='serif')
plt.xlabel('Number of Custers (K)', family='arial')
plt.ylabel('WCSS', family='arial')
plt.grid()
plt.tick_params(axis='both', direction='inout', length=6, color='red', grid_color='green', grid_linestyle='--')
plt.show()
# Out:
# C:\Users\SOURAV\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1036: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(

# %%
# training the model using k=4 as rendered by the above plot
kmean = KMeans(n_clusters=4, init='k-means++', random_state=90)
kmean.fit(X_pca)
# Out:
# KMeans(n_clusters=4, random_state=90)

# %%
# check the labels assigned to each data point
print(kmean.labels_)
# Out:
# [0 3 2 1 1 0 3 3 1 2 2 1 1 2 3 1 0 1 3 1 1 2 1 0 0 1 1 2 3 3 2 1 1 2 1 1 1
#  3 3 2 0 1 2 1 1 1 1 0 0 3 2 0 1 1 2 1 1 3 1 0 3 2 2 2 3 0 1 2 3 2 1 2 0 2
#  1 1 2 3 2 0 1 2 3 1 2 1 2 2 2 1 2 3 3 2 1 1 1 3 1 2 2 2 2]

# %%
# check the size of clusters
pd.Series(kmean.labels_).value_counts()
# Out:
# 1    39
# 2    32
# 3    19
# 0    13
# dtype: int64

# %%
# adding a new feature of cluster labels to the dataset 3
df3['clusters'] = kmean.labels_

# %%
# visualizing clusters
plt.figure(figsize=(7,5))
sns.scatterplot(data=df_pca, x='PC1', y='PC9', s=70, hue=kmean.labels_, palette='viridis', zorder=2, alpha=.9)
plt.scatter(x=kmean.cluster_centers_[:,0], y=kmean.cluster_centers_[:,1], marker="*", c="r", s=80, label="centroids")
plt.xlabel('PC1', family='arial', size=12)
plt.ylabel('PC9', family='arial', size=12)
plt.xticks(family='arial')
plt.yticks(family='arial')
plt.grid()
plt.tick_params(grid_color='green', grid_linestyle='--', zorder=1)
plt.legend(title='Labels', fancybox=True, shadow=True)
plt.title('K-Means Clustering Results', family='arial', size=15)
plt.show()
